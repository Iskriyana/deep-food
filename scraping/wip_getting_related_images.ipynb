# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /home/neuralcrypto/anaconda3/envs/deep-food/lib/python3.7/site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/neuralcrypto/anaconda3/envs/deep-food/lib/python3.7/site-packages (from requests) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/neuralcrypto/anaconda3/envs/deep-food/lib/python3.7/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/neuralcrypto/anaconda3/envs/deep-food/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /home/neuralcrypto/anaconda3/envs/deep-food/lib/python3.7/site-packages (from requests) (2.10)

# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.9.1-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.0.1-py3-none-any.whl (32 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.1 soupsieve-2.0.1

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in /home/neuralcrypto/anaconda3/envs/deep-food/lib/python3.7/site-packages (from selenium) (1.25.10)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
# !pip install webdriver
# Out:
# ERROR: Could not find a version that satisfies the requirement webdriver (from versions: none)
# ERROR: No matching distribution found for webdriver

# %%
from selenium import webdriver as wd

# %%
from selenium.webdriver.common.keys import Keys

# %%
path_chromedriver = '/home/neuralcrypto/Desktop/scraping/chromedriver_newest/chromedriver'

# %%
wd = webdriver.Chrome(executable_path=path_chromedriver)
wd.get('https://www.google.com/imghp')

# %%
search_box = wd.find_element_by_css_selector('input.gLFyf')
search_box.send_keys('one apple red')

# %% [markdown]
# Guide on how to use the keys of the keyboard and the arrows:
#
# https://artoftesting.com/press-enter-tab-space-arrow-function-keys-in-selenium-webdriver-with-java

# %%
search_box.send_keys(Keys.ENTER)

# %%
urls = wd.find_elements_by_class_name("rg_i.Q4LuWd")
len(urls)
# Out:
# 100

# %%
img_urls = [urls[i].get_attribute('src') for i in range(len(urls))]
img_urls_2 = [urls[i].get_attribute('data-src') for i in range(len(urls))]

# %% [markdown]
# Once the lists are created, I need to merge the datasets.

# %%
empty_index = []
for i, url in enumerate(img_urls):
    if url == None:
        empty_index.append(i)

# %%
for i in empty_index:
    img_urls[i] = img_urls_2[i]

# %%
img_urls
# Out:
# ['data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/png;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'data:image/jpeg;base64,...',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRXjnDL6mJEZA6XoJLDDRzYkWvsmSch-GkPxw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSSSLe-TMyNZRAHi0HLUNFTlNc679uvhJDEjA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRV2fiOqBxr9aXueONPah3BW_0MnTt_8JWNMQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQhzUBwchmeDqzuZLMXZTr4iw2DHYep_1BRwA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSu5SXFQ2br9I8SZuhYVYBOcRlsofbWN7AjZQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSQNFQyJi6PvXRaZhtVReray6FulEBQnaTnuw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT1biOB9uP6raIQtF4R37hfJlHWleEPyN9_ng&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRCPe8g6aqnGCRv3Gog7JIvdd-VKx1g8a53vg&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQezIocPACgFJcPBDSswl9VH3wbikp8c4Wktw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcThTXCYwG6r1MSXiwgjtnfUpr7hC3tiHSNTzw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSrE6UPvdURq-hBlLQi0UUqihB1CdLMgvIXAA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQtESTmoR7ePjiyekydhO3HsnJOsKn45v7r5A&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSeMq7OsboQbDynu-41Uy8J71sBME5AEQugEg&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQi8_2_sLxTraQFhQ7DD9_xMpZeQ1LNUzKQYw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQGop0PFxggyjPZCaGx_1weECDse7smlo58ww&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQuidv__YAjywKRwWCwPRqVlDNXY3-NC3mh1A&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSR_IK86eAVMhtMTQ4bK2kwCOw-EoHtVljPfA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT26tvKZAAKnLYfTbu3ExJb3gw7wEzojzIS-g&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ5bH8s2wAj9p01G809OZSDH7uCbYk8xCGvzg&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSIVGR7Ik9CpaGFdp_P9OZsYo5346JD_k6D7Q&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcT3oY24UhB0Lr58XqoVrzx86aseiRNY-tpQBA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcStnQN6QPH2-D-VYxeFyg2Lh6MYQqcLELFddw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSLsP6s69pG9LIbpDY9080LakK_M8amcwxdQg&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSPjTs2GiB76quNyOAWcLRmY6cE6VuOxwtOGA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSUOAGPU6RRQ2HuZiQxswsdMAEWd6d3ymu9yA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9Gc
&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRWqyLtWxFd0m5lIq27EJH8qmNmE-odkSeBZQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcTUKY4qZbXUdVOQRqiX2m7pvO7iUYejpjr7QQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQQ5Q5AwOCovoRwPzYZP1lrRhRfFa_K-XF27w&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQIN8zCMXCzbMjtJpWJRy950OGTIw9NTONOpg&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQYAsgzmweFm4w6aBnlNlDy-EnZ8I0XowJ65A&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRqj89ncegZw8IQQGyKbXzEh6lFqIUvtlIZEQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRY-_wBj4m9cwzHO2-KnSsmvYB8PLZM4qgNgQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRXhZvQwDztCF0e4aEo1A_V_vJIU6GNRDNfpg&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQbNnifL6qiUivTqlQ3jskxduD8ZVhAEAl0cw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSstiq2_2wFg6DPSryp_9agTZ0beWllVj0j2A&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRbl7jcnmtmtE42om1UD3uZ-O5xDRr27KcmVA&usqp=CAU']

# %%
print(len([img for img in img_urls_2 if img != None]))
# [img for img in img_urls_2 if img != None]
# Out:
# 80

# %%
from urllib import request
import numpy as np
from tqdm import tqdm

# %%
for j, url in

# %%
request.urlretrieve(img_urls[1], './data/kiwi/test.jpg')
# Out:
# ('./data/kiwi/test.jpg', <email.message.Message at 0x7f6b036d5490>)

# %% [markdown]
# ### Getting the SIMILAR images

# %%
import selenium
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %%
wd = webdriver.Chrome(executable_path=path_chromedriver)

wd.get('https://www.google.com/imghp')

search_box = wd.find_element_by_css_selector('input.gLFyf')
search_box.send_keys('fresh lemon nice')
search_box.send_keys(Keys.ENTER)

# %%
# With this method we click on the first name. Then we can tab a few times
wd.find_element_by_class_name("rg_i.Q4LuWd").click()

# %%
actions = ActionChains(wd)

# %% [markdown]
# ## Be careful because the ACTION CHAINS, get accumulated in the instance that you are using

# %% [markdown]
# Use .context_click() == right click
#
#
# (an example of how to do the right click on the image)
#
# Actions action= new Actions(driver);
# action.contextClick(productLink).sendKeys(Keys.ARROW_DOWN).sendKeys(Keys.ARROW_DOWN).sendKeys(Keys.RETURN).build().perform();

# %%
actions.send_keys(Keys.TAB).perform()

# %%
ActionChains(wd).send_keys(Keys.SHIFT).send_keys(Keys.F10).send_keys(Keys.ARROW_DOWN).send_keys(Keys.ENTER).perform()

# %%
ActionChains(wd).context_click().perform()

# %%
ActionChains(wd).double_click().perform()

# %%
actions.send_keys(Keys.ARROW_DOWN).perform()

# %%
actions.click().perform()

# %%
actions.key_down(1).

# %%
# Making a screenshot, nice
# wd.save_screenshot('testing_screenshot.png')

# %% [markdown]
# ## THIS IS JUST CRAZY COOL! by specifiying the self.driver, in our case wd, we can do the Action Chains

# %%
wd.switch_to_window()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-158-fbf3b20c628d> in <module>
# ----> 1 wd.switch_to_window()
#
# TypeError: switch_to_window() missing 1 required positional argument: 'window_name'

# %%
wd.switch_to.active_element()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-2a4bb42218a6> in <module>
# ----> 1 wd.switch_to.active_element()
#
# TypeError: 'WebElement' object is not callable

# %%
actions = ActionChains(wd)

# %%
actions.send_keys(Keys.TAB)

# %%
wd.quit()

# %%
selenium.webdriver.Chrome(path_chromedriver)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="88c1f3fbdc9fe56a79b120665b5235b0")>

# %%
path_chromedriver
# Out:
# '/home/neuralcrypto/Desktop/scraping/chromedriver_newest/chromedriver'
